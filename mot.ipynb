# %% [markdown]
# ## 最適化の検証

# %%
import pandas as pd

df = pd.read_csv("booklist.csv")
df
# Out:
#         name       title  price
# 0      yukie  たのしいPython   3000
# 1   altnight  たのしいPython   3000
# 2       furi  たのしいPython   3000
# 3        mtb  たのしいPython   3000
# 4   susumuis  おいしいPython   1000
# 5   altnight   やさしいNumPy   4000
# 6      yukie   やさしいNumPy   4000
# 7        mtb   やさしいNumPy   4000
# 8      yukie     難しい機械学習   2000
# 9        mtb     難しい機械学習   2000
# 10     yukie  かんたんDjango   2500
# 11  susumuis  かんたんDjango   2500

# %%
# 既読
titles_set = df.loc[df["name"] == "susumuis", "title"].unique()

# 未読
df_filtered = df[~df["title"].isin(titles_set)]

# %%
df_books = (
    df_filtered.groupby("title")
        .agg({"name": "nunique", "price": "first"})
        .reset_index()
        .rename(columns={"name": "n_readers"})
)
df_books
# Out:
#         title  n_readers  price
# 0  たのしいPython          4   3000
# 1   やさしいNumPy          3   4000
# 2     難しい機械学習          2   2000

# %%
from mip import Model

m = Model()
# 変数: 書籍をおすすめする = 1, しない = 0
df_books["Var_x"] = m.add_var_tensor((len(df_books),), "x", var_type="B")
df_books
# Out:
#         title  n_readers  price Var_x
# 0  たのしいPython          4   3000   x_0
# 1   やさしいNumPy          3   4000   x_1
# 2     難しい機械学習          2   2000   x_2

# %%
from mip import maximize, xsum

# 目的関数: 同僚の多くが読んでいる書籍をなるべく多く薦める
m.objective = maximize(xsum(df_books["n_readers"] * df_books["Var_x"]))

# 制約条件: 金額が予算以内
m += xsum(df_books["price"] * df_books["Var_x"]) <= 5000

# %%
m.optimize()
df_books["Val_x"] = df_books["Var_x"].astype(float)
df_books
# Out:
# Welcome to the CBC MILP Solver
# Version: Trunk
# Build Date: Oct 24 2021
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 3 (0) columns and 3 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 3 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-3) columns and 0 (-3) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0000I Optimal - objective value 6
# Clp0000I Optimal - objective value 6
# Clp0000I Optimal - objective value 6
# Clp0032I Optimal objective 6 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
#         title  n_readers  price Var_x  Val_x
# 0  たのしいPython          4   3000   x_0    1.0
# 1   やさしいNumPy          3   4000   x_1    0.0
# 2     難しい機械学習          2   2000   x_2    1.0

# %%
# お薦めする書籍のタイトルの一覧だけを取得したい場合は、次のように記述する（誤差による不具合を防ぐために0.5を境界として比較する）
df_books[df_books["Val_x"] > 0.5]["title"].to_list()
# Out:
# ['たのしいPython', '難しい機械学習']

# %%
def optimize_book_to_buy(name, money):
    # 既読
    titles_set = df.loc[df["name"] == name, "title"].unique()
    # 未読
    df_filtered = df[~df["title"].isin(titles_set)]

    df_books = (
        df_filtered.groupby("title")
            .agg({"name": "nunique", "price": "first"})
            .reset_index()
            .rename(columns={"name": "n_readers"})
    )

    m = Model()
    # 変数: 書籍をおすすめする = 1, しない = 0
    df_books["Var_x"] = m.add_var_tensor((len(df_books),), "x", var_type="B")
    # 目的関数: 同僚の多くが読んでいる書籍をなるべく多く薦める
    m.objective = maximize(xsum(df_books["n_readers"] * df_books["Var_x"]))
    # 制約条件: 金額が予算以内
    m += xsum(df_books["price"] * df_books["Var_x"]) <= money

    # 最適化実行
    m.optimize()
    df_books["Val_x"] = df_books["Var_x"].astype(float)
    # お薦めする書籍のタイトルの一覧だけを取得したい場合は、次のように記述する（誤差による不具合を防ぐために0.5を境界として比較する）
    return df_books[df_books["Val_x"] > 0.5]["title"].to_list()

# %%
results = []
for name in df["name"].unique():
    for money in [1000, 2000, 3000, 4000, 5000]:
        book_to_buy = optimize_book_to_buy(name, money)
        results.append((name, money, book_to_buy))
result_df = pd.DataFrame(results, columns=["name", "money", "book_to_buy"])
result_df
# Out:
# Cgl0004I processed model has 1 rows, 3 columns (3 integer (3 of which binary)) and 3 elements
# Coin3009W Conflict graph built in 0.001 seconds, density: 23.810%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 3.6e-05
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -6
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -6 - took 0.00 seconds
# Cbc0012I Integer solution of -6 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -6, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 0 (-1) rows, 0 (-1) columns and 0 (-1) elements
# Clp0000I Optimal - objective value 1
# Coin0511I After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 1 - 0 iterations time 0.002, Presolve 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 0 (-1) rows, 0 (-1) columns and 0 (-1) elements
# Clp0000I Optimal - objective value 1
# Coin0511I After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 1 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 0 (-1) rows, 0 (-1) columns and 0 (-1) elements
# Clp0000I Optimal - objective value 1
# Coin0511I After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 1 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 0 (-1) rows, 0 (-1) columns and 0 (-1) elements
# Clp0000I Optimal - objective value 1
# Coin0511I After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 1 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 0 (-1) rows, 0 (-1) columns and 0 (-1) elements
# Clp0000I Optimal - objective value 1
# Coin0511I After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 1 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 3 (0) columns and 3 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 3 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-3) columns and 0 (-3) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 6.999997 (3)
# Clp0000I Optimal - objective value 1
# Clp0000I Optimal - objective value 1
# Clp0000I Optimal - objective value 1
# Clp0032I Optimal objective 1 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 3 (0) columns and 3 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 3 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-3) columns and 0 (-3) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 6.999997 (3)
# Clp0000I Optimal - objective value 2
# Clp0000I Optimal - objective value 2
# Clp0000I Optimal - objective value 2
# Clp0032I Optimal objective 2 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 1 rows, 2 columns (2 integer (2 of which binary)) and 2 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 30.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 0.000215
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -2
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -2 - took 0.00 seconds
# Cbc0012I Integer solution of -2 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -2, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 3 (0) columns and 3 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 3 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-3) columns and 0 (-3) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 6.999997 (3)
# Clp0000I Optimal - objective value 3
# Clp0000I Optimal - objective value 3
# Clp0000I Optimal - objective value 3
# Clp0032I Optimal objective 3 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 1 rows, 3 columns (3 integer (3 of which binary)) and 3 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 23.810%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 2.3e-05
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -3
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -3 - took 0.00 seconds
# Cbc0012I Integer solution of -3 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -3, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 3 (0) columns and 3 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 3 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-3) columns and 0 (-3) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 6.999997 (3)
# Clp0000I Optimal - objective value 3.8
# Clp0000I Optimal - objective value 3.8
# Clp0000I Optimal - objective value 3.8
# Clp0032I Optimal objective 3.8 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
# Cgl0003I 1 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 3 (0) columns and 3 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 3 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-3) columns and 0 (-3) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 6.999997 (3)
# Clp0000I Optimal - objective value 4.6
# Clp0000I Optimal - objective value 4.6
# Clp0000I Optimal - objective value 4.6
# Clp0032I Optimal objective 4.6 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 1 rows, 1 columns (1 integer (0 of which binary)) and 1 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 0.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 1.7e-05
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -4
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -4 - took 0.00 seconds
# Cbc0012I Integer solution of -4 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -4, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 4 (0) columns and 4 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 4 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-4) columns and 0 (-4) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 14.199996 (4)
# Clp0000I Optimal - objective value 1
# Clp0000I Optimal - objective value 1
# Clp0000I Optimal - objective value 1
# Clp0032I Optimal objective 1 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 4 (0) columns and 4 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 4 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-4) columns and 0 (-4) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 14.199996 (4)
# Clp0000I Optimal - objective value 2
# Clp0000I Optimal - objective value 2
# Clp0000I Optimal - objective value 2
# Clp0032I Optimal objective 2 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 1 rows, 2 columns (2 integer (2 of which binary)) and 2 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 30.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 1.8e-05
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -2
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -2 - took 0.00 seconds
# Cbc0012I Integer solution of -2 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -2, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 4 (0) columns and 4 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 4 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-4) columns and 0 (-4) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 14.199996 (4)
# Clp0000I Optimal - objective value 3
# Clp0000I Optimal - objective value 3
# Clp0000I Optimal - objective value 3
# Clp0032I Optimal objective 3 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 1 rows, 3 columns (3 integer (3 of which binary)) and 3 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 23.810%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 2.4e-05
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -3
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -3 - took 0.00 seconds
# Cbc0012I Integer solution of -3 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -3, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 4 (0) columns and 4 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 4 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-4) columns and 0 (-4) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 14.199996 (4)
# Clp0000I Optimal - objective value 3.8
# Clp0000I Optimal - objective value 3.8
# Clp0000I Optimal - objective value 3.8
# Clp0032I Optimal objective 3.8 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 1 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 1 rows, 3 columns (3 integer (3 of which binary)) and 3 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 23.810%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 2.3e-05
# Cbc0038I Initial state - 1 integers unsatisfied sum - 0.25
# Cbc0038I Pass   1: suminf.    0.25000 (1) obj. -3.25 iterations 0
# Cbc0038I Solution found of -1
# Cbc0038I Rounding solution of -3 is better than previous of -1
#
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -3 - took 0.00 seconds
# Cbc0012I Integer solution of -3 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -3, took 1 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 2 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 4 (0) columns and 4 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 4 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-4) columns and 0 (-4) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 14.199996 (4)
# Clp0000I Optimal - objective value 4.6
# Clp0000I Optimal - objective value 4.6
# Clp0000I Optimal - objective value 4.6
# Clp0032I Optimal objective 4.6 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 1 rows, 4 columns (4 integer (4 of which binary)) and 4 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 16.667%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 2.3e-05
# Cbc0038I Initial state - 1 integers unsatisfied sum - 0.2
# Cbc0038I Pass   1: suminf.    0.20000 (1) obj. -4.6 iterations 0
# Cbc0038I Solution found of -3
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1 rows 4 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of -4.05991
# Cbc0038I Pass   2: suminf.    0.20000 (1) obj. -4.6 iterations 0
# Cbc0038I Pass   3: suminf.    0.35330 (1) obj. -4.05991 iterations 2
# Cbc0038I Pass   4: suminf.    0.50000 (1) obj. -4.5 iterations 1
# Cbc0038I Pass   5: suminf.    0.50000 (1) obj. -4.5 iterations 0
# Cbc0038I Pass   6: suminf.    0.20000 (1) obj. -4.6 iterations 1
# Cbc0038I Pass   7: suminf.    0.01997 (1) obj. -4.05991 iterations 3
# Cbc0038I Pass   8: suminf.    0.12500 (1) obj. -4.375 iterations 1
# Cbc0038I Pass   9: suminf.    0.01997 (1) obj. -4.05991 iterations 1
# Cbc0038I Pass  10: suminf.    0.20000 (1) obj. -4.6 iterations 3
# Cbc0038I Pass  11: suminf.    0.20000 (1) obj. -4.6 iterations 0
# Cbc0038I Pass  12: suminf.    0.01997 (1) obj. -4.05991 iterations 3
# Cbc0038I Pass  13: suminf.    0.01997 (1) obj. -4.05991 iterations 0
# Cbc0038I Pass  14: suminf.    0.31336 (1) obj. -4.05991 iterations 1
# Cbc0038I Pass  15: suminf.    0.25000 (1) obj. -4.25 iterations 1
# Cbc0038I Pass  16: suminf.    0.31336 (1) obj. -4.05991 iterations 1
# Cbc0038I Pass  17: suminf.    0.31336 (1) obj. -4.05991 iterations 0
# Cbc0038I Pass  18: suminf.    0.31336 (1) obj. -4.05991 iterations 0
# Cbc0038I Pass  19: suminf.    0.31336 (1) obj. -4.05991 iterations 0
# Cbc0038I Pass  20: suminf.    0.31336 (1) obj. -4.05991 iterations 0
# Cbc0038I Pass  21: suminf.    0.50000 (1) obj. -4.5 iterations 2
# Cbc0038I Pass  22: suminf.    0.35330 (1) obj. -4.05991 iterations 1
# Cbc0038I Pass  23: suminf.    0.50000 (1) obj. -4.5 iterations 1
# Cbc0038I Pass  24: suminf.    0.20000 (1) obj. -4.6 iterations 1
# Cbc0038I Pass  25: suminf.    0.20000 (1) obj. -4.6 iterations 0
# Cbc0038I Pass  26: suminf.    0.20000 (1) obj. -4.6 iterations 0
# Cbc0038I Pass  27: suminf.    0.20000 (1) obj. -4.6 iterations 0
# Cbc0038I Pass  28: suminf.    0.01997 (1) obj. -4.05991 iterations 3
# Cbc0038I Pass  29: suminf.    0.12500 (1) obj. -4.375 iterations 1
# Cbc0038I Pass  30: suminf.    0.01997 (1) obj. -4.05991 iterations 1
# Cbc0038I Pass  31: suminf.    0.80991 (2) obj. -4.05991 iterations 1
# Cbc0038I Rounding solution of -4 is better than previous of -3
#
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -4 - took 0.00 seconds
# Cbc0012I Integer solution of -4 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -4, took 1 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 3 variables fixed on reduced cost
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 0 (-1) rows, 0 (-2) columns and 0 (-2) elements
# Clp0000I Optimal - objective value 1
# Coin0511I After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 1 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 0 (-1) rows, 0 (-2) columns and 0 (-2) elements
# Clp0000I Optimal - objective value 1.8
# Coin0511I After Postsolve, objective 1.8, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 1.8 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 2 (0) columns and 2 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 2 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-2) columns and 0 (-2) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 4.499998 (2)
# Clp0000I Optimal - objective value 2.6
# Clp0000I Optimal - objective value 2.6
# Clp0000I Optimal - objective value 2.6
# Clp0032I Optimal objective 2.6 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 0 (-1) rows, 0 (-2) columns and 0 (-2) elements
# Clp0000I Optimal - objective value 3
# Coin0511I After Postsolve, objective 3, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 3 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 0 (-1) rows, 0 (-2) columns and 0 (-2) elements
# Clp0000I Optimal - objective value 3
# Coin0511I After Postsolve, objective 3, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 3 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 3 (0) columns and 3 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 3 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-3) columns and 0 (-3) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 12.33333 (3)
# Clp0000I Optimal - objective value 1.3333333
# Clp0000I Optimal - objective value 1.3333333
# Clp0000I Optimal - objective value 1.3333333
# Clp0032I Optimal objective 1.333333333 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 3 (0) columns and 3 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 3 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-3) columns and 0 (-3) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 12.33333 (3)
# Clp0000I Optimal - objective value 2.6666667
# Clp0000I Optimal - objective value 2.6666667
# Clp0000I Optimal - objective value 2.6666667
# Clp0032I Optimal objective 2.666666667 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 3 (0) columns and 3 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 3 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-3) columns and 0 (-3) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 12.33333 (3)
# Clp0000I Optimal - objective value 4
# Clp0000I Optimal - objective value 4
# Clp0000I Optimal - objective value 4
# Clp0032I Optimal objective 4 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 1 rows, 2 columns (2 integer (2 of which binary)) and 2 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 30.000%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 1.8e-05
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -4
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -4 - took 0.00 seconds
# Cbc0012I Integer solution of -4 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -4, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 3 (0) columns and 3 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 3 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-3) columns and 0 (-3) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 12.33333 (3)
# Clp0000I Optimal - objective value 5
# Clp0000I Optimal - objective value 5
# Clp0000I Optimal - objective value 5
# Clp0032I Optimal objective 5 - 0 iterations time 0.002, Idiot 0.00
#
# Starting MIP optimization
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc3007W No integer variables
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 1 (0) rows, 3 (0) columns and 3 (0) elements
# Clp1000I sum of infeasibilities 0 - average 0, 3 fixed columns
# Coin0506I Presolve 0 (-1) rows, 0 (-3) columns and 0 (-3) elements
# Clp0000I Optimal - objective value -0
# Clp0000I Optimal - objective value -0
# Coin0511I After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj -0 Dual inf 12.33333 (3)
# Clp0000I Optimal - objective value 6
# Clp0000I Optimal - objective value 6
# Clp0000I Optimal - objective value 6
# Clp0032I Optimal objective 6 - 0 iterations time 0.002
#
# Starting MIP optimization
#         name  money               book_to_buy
# 0      yukie   1000              [おいしいPython]
# 1      yukie   2000              [おいしいPython]
# 2      yukie   3000              [おいしいPython]
# 3      yukie   4000              [おいしいPython]
# 4      yukie   5000              [おいしいPython]
# 5   altnight   1000              [おいしいPython]
# 6   altnight   2000                 [難しい機械学習]
# 7   altnight   3000     [おいしいPython, 難しい機械学習]
# 8   altnight   4000  [おいしいPython, かんたんDjango]
# 9   altnight   5000     [かんたんDjango, 難しい機械学習]
# 10      furi   1000              [おいしいPython]
# 11      furi   2000                 [難しい機械学習]
# 12      furi   3000     [おいしいPython, 難しい機械学習]
# 13      furi   4000  [おいしいPython, かんたんDjango]
# 14      furi   5000     [かんたんDjango, 難しい機械学習]
# 15       mtb   1000              [おいしいPython]
# 16       mtb   2000              [おいしいPython]
# 17       mtb   3000              [かんたんDjango]
# 18       mtb   4000  [おいしいPython, かんたんDjango]
# 19       mtb   5000  [おいしいPython, かんたんDjango]
# 20  susumuis   1000                        []
# 21  susumuis   2000                 [難しい機械学習]
# 22  susumuis   3000              [たのしいPython]
# 23  susumuis   4000              [たのしいPython]
# 24  susumuis   5000     [たのしいPython, 難しい機械学習]
